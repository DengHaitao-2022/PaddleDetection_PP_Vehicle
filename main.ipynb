# %%
import paddle

paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
# !python deploy/pipeline/pipeline.py --config deploy/pipeline/config/infer_cfg_ppvehicle_all.yml \
                                                    --video_file=../../data/video/01_1080p.mp4 \
                                                   --device=gpu \
                                                   --draw_center_traj # 开启绘制中心轨迹
